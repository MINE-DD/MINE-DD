# %%
from pydantic import BaseModel, Field
import os
from pathlib import Path
import json

# %%
class Measurement(BaseModel):
    measurement_type: str = Field(
        description="The type of measurement (e.g., Relative Humidity, Specific Humidity)."
    )
    description: str = Field(
        description="Description of how the measurement is computed or estimated."
    )
    formula: list[str] | None = Field(
        description="Formula(s) used for computation, if applicable."
    )
    variables: list[str] | None = Field(
        description="Variables used in the formulas."
    )
    notes: str | None = Field(
        description="Additional notes about the measurement, such as handling of missing data."
    )

class WeatherData(BaseModel):
    time_period: str | None = Field(
        description='Time in which weather data was collected, or time window in which environmental variables were monitored',
        examples=['Precipitation was collected during the monsoon season', 'monthly weather data were monitored between 2001 and 2012']
    )
    details: list[str] | None = Field(
        description='Any sentence from the paper describing any info related to weather data that cannot be captured well in the above fields',
        examples='Precipitations in Bangladesh were scarse during the 2005 fall'
    )
    measurement: list[Measurement] = Field(
        description="List of different measurements and methodologies used in the study."
    )

# %%
class Methodology(BaseModel):
    name: str | None = Field(
        description='Name of the methodology used',
        examples=['t-test', 'signal processing']
    )
    description: str | None = Field(
        description='Literal text, Description of the methodology'
    )
    methods: list[str] | None = Field(
        description='Specific methods or techniques used within the methodology',
        examples='Fast fourier transformation'
    )
    goals: list[str] | None = Field(
        description='Goals or purposes of using the methodology'
    )

class StudyScope(BaseModel):
    study_sites: list[str] | None = Field(
        description='sites studied and mentioned in the paper',
        examples=['The Gambia', 'Mali']
    ),
    description: list[str] | None = Field(
        description='Sites/setting description in sentences which not necessarily contain the name of the site',
        examples='resource limited setting'
    ),
    locations: list[str] = Field(
        description='Names of the actual locations'
    )


class StudyDuration(BaseModel):
    duration: str | None = Field(
        description='The duration of the study described in the paper',
        examples=['three years', '6 months', 'the study ran over 10 years']
    )
    details: list[str] | None  = Field(
        description='Actual sentences whereby the duration is mentioned. It is possible in this field to have multiple durations mentioned'
    )

class ParticipantAgeGroup(BaseModel):
    age_range: str | None = Field(
        description='Age range of the population described in the paper. If there is no range, also age in months/years is fine',
        examples=['36 months old', 'children younger than five years of age']
    )
    details: list[str] | None = Field(
        description='Any descriptive sentence that details who the participants were, how old they were and any other information that relates to them',
        examples=['Children 0–59 months of age with moderate-to-severe diarrhea (MSD)', 'Only the first 8–9 children in each age strata (0–11 months, 12–23 months, 24–59 months) were recruited']
    )




class Bibliography(BaseModel):
    article_type: str | None = Field(
        description='Article type', 
        examples=['Research article', ' meta-analysis', 'review', 'opinion paper']
    )
    study_type: str | None = Field(
        description='Type of study',
        examples=['retrospective study']
    )
    title: str = Field(
        description='Title of the paper'
    )
    study_scope: StudyScope = []
    methodology: list[Methodology] = []
    study_duration: StudyDuration = [] 
    participant_age_group: ParticipantAgeGroup = []
    weather_data: WeatherData = [] 
    data_collection: str = Field(
        description='When data was collected?',
        examples=['during 2008 to 2011']
    )
    authors: str = Field(
        description='Authors of the paper. Usually listed below the title in the first page of the paper',
        examples=['Roose, A., Washington, D., Aniston, J.A.']
    )
    affiliation: str = Field(
        description='Affiliations of the authors listed in the authors field',
        examples=['Institute for Disease Modeling, Bellevue, Washington', 'International School for Advanced Studies, Trieste, Italy']
    )
    citation: str | None = Field(
        description='Citation of the paper which typically includes the first author surname followed by et al., and the year of publication along with the name of the journal',
        examples=['Roose et al., 2008, BMJ']
    )
    corresponding_author: str = Field(
        description='Author that has made available their email for further contact',
        examples=['r.roosevelt@gmail.com']
    )
    doi: str | None 
    date: str = Field(
        description='Date in which the paper has been published comprising typically day, month and year',
        examples=['06-08-2013']
    )
    github_repo: str | None = Field(
        description='Github repository where code and data are available.',
        examples='https://github.com/papermanuscript/main'
    )
    journal: str = Field(
        description='Name of the journal in which the paper has been published, tipically listed in the front page, nearby the title',
        examples= 'PLoS Negl Trop Dis'
    )

# %%
local_path = Path(os.getcwd())
data = 'bib_schema.json'

json_path = local_path / data

# %%
with json_path.open('r') as file:
    data = json.load(file)

# %%
for doc in data:
    model = Bibliography(**doc)
    print(f'---------- \n {model.json()} \n')
# Out:
# ----------
#  {"article_type":"RESEARCH ARTICLE","study_type":"retrospective study","title":"The seasonality of diarrheal pathogens: A retrospective study of seven sites over three years","study_scope":{"study_sites":["seven sites of the Global Enteric Multicenter Study (GEMS)","seven communities in sub-Saharan Africa (Basse, The Gambia; Bamako, Mali; Nyaza Province, Kenya; Manhiça, Mozambique) and South Asia (Karachi [Bin Qasim Town], Pakistan; Kolkata, India; Mirzapur, Bangladesh)"],"description":["multi-site, multi-continent study","a large, multi-country study","resource limited settings"],"locations":["The Gambia","Mali","Kenya","Mozambique","Pakistan","India","Bangladesh"]},"methodology":[{"name":"Signal Processing Methods","description":"Traditional methodologies from signal processing used to detect periodicity in time series data.","methods":["Lomb–Scargle periodogram","Fast Fourier transforms"],"goals":["Estimate the annual, biannual, and other seasonal signals for each pathogen at each site."]},{"name":"Uncertainty Quantification","description":"Quantification of uncertainty of each estimate to mitigate the impact of intrinsic stochasticity.","methods":[""],"goals":[""]},{"name":"Machine Learning","description":"Site-dependent seasons through the use of machine-learning methodologies performed on local weather data.","methods":[""],"goals":["Data-driven seasons","Broadly characterize the seasonality"]},{"name":"Data Usage","description":"Pathogen prevalence data for each site.","methods":[""],"goals":[""]}],"study_duration":{"duration":"three years","details":["Global Enteric Multicenter Study (GEMS) was conducted for 36 consecutive months from December 2007 to March 2011"]},"participant_age_group":{"age_range":"children younger than five years of age","details":["GEMS enrolled 9,439 out of 14,753 eligible children with MSD during the study period","Children 0–59 months of age with moderate-to-severe diarrhea (MSD)","Episode needed to be new (onset after at least seven days without diarrhea), acute (onset within seven days), and had to meet at least one clinical criterion for MSD. Clinical criteria for MSD included the following: the child presents clinical signs of dehydration, i.e., sunken eyes or loss of skin turgor, assessed by clinician and confirmed by mother, prescription or use of intravenous hydration; dysentery identified by blood in stool; or admission to the hospital for diarrhea or dysentery.","Only the first 8–9 children in each age strata (0–11 months, 12–23 months, 24–59 months) were recruited each fortnight (14 days)"]},"weather_data":{"time_period":"2008 to 2011","details":["monthly weather data collected from the closest weather station in Bangladesh","Daily historical weather data from weather stations were acquired from the Global Surface Summary of the Day (GSOD)"],"measurement":[{"measurement_type":"Relative Humidity","description":"Computed using the following empirical relationship.","formula":["RH = 100 * ((112 - (0.1 * T) + DP / (112 + (0.9 * T)))^8"],"variables":["Temperature in Celsius","Dewpoint in Celsius","Relative Humidity"],"notes":""},{"measurement_type":"Specific Humidity","description":"Estimated using the following empirical relationships.","formula":["P = 101.3 * e^(-EL / 8200)","Es = 0.622 * e^(17.502 * T) / (T + 240.97)","E = (0.01 * RH) * Es","E = (0.622 * E) / (P - E)","SH = 1000 * W / (1 + W)"],"variables":["Elevation in meters","Air pressure in kPa","Saturation vapor pressure in kPa","Vapor pressure in kPa","Relative Humidity","Mixing ratio","Specific Humidity in g/kg"],"notes":"Days with missing rainfall data were assumed to have no rainfall, and days with missing temperature or humidity data were not included when computing average temperature or humidity for the fortnight or month containing them."}]},"data_collection":"monthly weather data collected from the closest weather station in Bangladesh during 2008 to 2011","authors":"Dennis L. ChaoID1*, Anna Roose2, Min RohID1, Karen L.  ...
#
# ----------
#  {"article_type":"Articles","study_type":"","title":"Use of earth observation-derived hydrometeorological  variables to model and predict rotavirus infection (MAL-ED):  a multisite cohort study","study_scope":{"study_sites":[""],"description":[""],"locations":[""]},"methodology":[{"name":"","description":"","methods":[""],"goals":[""]}],"study_duration":{"duration":"","details":[""]},"participant_age_group":{"age_range":"","details":[]},"weather_data":{"time_period":"","details":[""],"measurement":[{"measurement_type":"","description":"","formula":[""],"variables":[],"notes":""}]},"data_collection":"","authors":"Josh M Colston, Benjamin Zaitchik, Gagandeep Kang, Pablo Peñataro Yori, Tahmeed Ahmed, Aldo Lima, Ali Turab, Esto Mduma,  Prakash Sunder Shrestha, Pascal Bessong, Roger D Peng, Robert E Black, Lawrence H Moulton, Margaret N Kosek","affiliation":"Department of International  Health (J M Colston PhD,  P Peñataro Yori MPH,  Prof R E Black MD,  Prof L H Moulton PhD,  M N Kosek MD),  and Department of  Biostatistics  (Prof R D Peng PhD), Johns  Hopkins Bloomberg School of  Public Health, Baltimore, MD,  USA; Department of Earth  and Planetary Sciences, Johns  Hopkins Krieger School of Arts  and Sciences, Baltimore, MD,  USA (B Zaitchik PhD); Christian  Medical College, Vellore, India  (Prof G Kang MD); Nutrition  & Clinical Services Division,  International Centre for  Diarrhoeal Disease Research,  Bangladesh (icddr,b), Dhaka,  Bangladesh (T Ahmed PhD);  Federal University of Ceará,  Fortaleza, Brazil (A Lima PhD);  Interactive Research and  Development, Maternal  and Child Health (MCH)  Program, Karachi, Pakistan  (A Turab MD); Haydom Global  Health Institute, Haydom,  Tanzania (E Mduma MSc);  Department of Child Health,  Institute of Medicine of  Tribhuvan University,  Kathmandu, Nepal  (P Sunder Shrestha MD);  and University of Venda,  Thohoyandou, South Africa  (Prof P Bessong PhD)","citation":"","corresponding_author":"mkosek@jhu.edu","doi":"","date":"June 2019","github_repo":"","journal":"Lancet Planet Health"}
#
# ----------
#  {"article_type":"RESEARCH ARTICLE","study_type":"","title":"Seasonality and the effects of weather on Campylobacter infections","study_scope":{"study_sites":[""],"description":[""],"locations":[""]},"methodology":[{"name":"","description":"","methods":[""],"goals":[""]}],"study_duration":{"duration":"","details":[""]},"participant_age_group":{"age_range":"","details":[]},"weather_data":{"time_period":"","details":[""],"measurement":[{"measurement_type":"","description":"","formula":[""],"variables":[],"notes":""}]},"data_collection":"","authors":"Abdelmajid Djennad1*, Giovanni Lo Iacono2, Christophe Sarran3, Christopher Lane4, Richard Elson5,6, Christoph Höser7, Iain R. Lake8, Felipe J. Colón-González8, Sari Kovats9, Jan C. Semenza10, Trevor C. Bailey11, Anthony Kessel1,9, Lora E. Fleming11 and Gordon L. Nichols1","affiliation":"Statistics, Modelling and Economics Department, National Infection Service, Public Health England, 61, Colindale Avenue, London NW9 5EQ, UK","citation":"Djennad et al. BMC Infectious Diseases (2019)","corresponding_author":"abdelmajid.djennad@phe.gov.uk","doi":"https://doi.org/10.1186/s12879-019-3840-7","date":"2019","github_repo":"","journal":"BMC Infectious Diseases"}
#
# ----------
#  {"article_type":"","study_type":"","title":"","study_scope":{"study_sites":[""],"description":[""],"locations":[""]},"methodology":[{"name":"","description":"","methods":[""],"goals":[""]}],"study_duration":{"duration":"","details":[""]},"participant_age_group":{"age_range":"","details":[]},"weather_data":{"time_period":"","details":[""],"measurement":[{"measurement_type":"","description":"","formula":[""],"variables":[],"notes":""}]},"data_collection":"","authors":"","affiliation":"","citation":"","corresponding_author":"","doi":"","date":"","github_repo":"","journal":""}

# %%
model.dict()
# Out:
# {'article_type': '',
#  'study_type': '',
#  'title': '',
#  'study_scope': {'study_sites': [''], 'description': [''], 'locations': ['']},
#  'methodology': [{'name': '',
#    'description': '',
#    'methods': [''],
#    'goals': ['']}],
#  'study_duration': {'duration': '', 'details': ['']},
#  'participant_age_group': {'age_range': '', 'details': []},
#  'weather_data': {'time_period': '',
#   'details': [''],
#   'measurement': [{'measurement_type': '',
#     'description': '',
#     'formula': [''],
#     'variables': [],
#     'notes': ''}]},
#  'data_collection': '',
#  'authors': '',
#  'affiliation': '',
#  'citation': '',
#  'corresponding_author': '',
#  'doi': '',
#  'date': '',
#  'github_repo': '',
#  'journal': ''}

# %%
# save the model to a json file so that we can share the schema
print(Bibliography.schema_json(indent=3))
# Out:
# {
#    "$defs": {
#       "Measurement": {
#          "properties": {
#             "measurement_type": {
#                "description": "The type of measurement (e.g., Relative Humidity, Specific Humidity).",
#                "title": "Measurement Type",
#                "type": "string"
#             },
#             "description": {
#                "description": "Description of how the measurement is computed or estimated.",
#                "title": "Description",
#                "type": "string"
#             },
#             "formula": {
#                "anyOf": [
#                   {
#                      "items": {
#                         "type": "string"
#                      },
#                      "type": "array"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Formula(s) used for computation, if applicable.",
#                "title": "Formula"
#             },
#             "variables": {
#                "anyOf": [
#                   {
#                      "items": {
#                         "type": "string"
#                      },
#                      "type": "array"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Variables used in the formulas.",
#                "title": "Variables"
#             },
#             "notes": {
#                "anyOf": [
#                   {
#                      "type": "string"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Additional notes about the measurement, such as handling of missing data.",
#                "title": "Notes"
#             }
#          },
#          "required": [
#             "measurement_type",
#             "description",
#             "formula",
#             "variables",
#             "notes"
#          ],
#          "title": "Measurement",
#          "type": "object"
#       },
#       "Methodology": {
#          "properties": {
#             "name": {
#                "anyOf": [
#                   {
#                      "type": "string"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Name of the methodology used",
#                "examples": [
#                   "t-test",
#                   "signal processing"
#                ],
#                "title": "Name"
#             },
#             "description": {
#                "anyOf": [
#                   {
#                      "type": "string"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Literal text, Description of the methodology",
#                "title": "Description"
#             },
#             "methods": {
#                "anyOf": [
#                   {
#                      "items": {
#                         "type": "string"
#                      },
#                      "type": "array"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Specific methods or techniques used within the methodology",
#                "examples": "Fast fourier transformation",
#                "title": "Methods"
#             },
#             "goals": {
#                "anyOf": [
#                   {
#                      "items": {
#                         "type": "string"
#                      },
#                      "type": "array"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Goals or purposes of using the methodology",
#                "title": "Goals"
#             }
#          },
#          "required": [
#             "name",
#             "description",
#             "methods",
#             "goals"
#          ],
#          "title": "Methodology",
#          "type": "object"
#       },
#       "ParticipantAgeGroup": {
#          "properties": {
#             "age_range": {
#                "anyOf": [
#                   {
#                      "type": "string"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Age range of the population described in the paper. If there is no range, also age in months/years is fine",
#                "examples": [
#                   "36 months old",
#                   "children younger than five years of age"
#                ],
#                "title": "Age Range"
#             },
#             "details": {
#                "anyOf": [
#                   {
#                      "items": {
#                         "type": "string"
#                      },
#                      "type": "array"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Any descriptive sentence that details who the participants were, how old they were and any other information that relates to them",
#                "examples": [
#                   "Children 0\u201359 months of age with moderate-to-severe diarrhea (MSD)",
#                   "Only the first 8\u20139 children in each age strata (0\u201311 months, 12\u201323 months, 24\u201359 months) were recruited"
#                ],
#                "title": "Details"
#             }
#          },
#          "required": [
#             "age_range",
#             "details"
#          ],
#          "title": "ParticipantAgeGroup",
#          "type": "object"
#       },
#       "StudyDuration": {
#          "properties": {
#             "duration": {
#                "anyOf": [
#                   {
#                      "type": "string"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "The duration of the study described in the paper",
#                "examples": [
#                   "three years",
#                   "6 months",
#                   "the study ran over 10 years"
#                ],
#                "title": "Duration"
#             },
#             "details": {
#                "anyOf": [
#                   {
#                      "items": {
#                         "type": "string"
#                      },
#                      "type": "array"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Actual sentences whereby the duration is mentioned. It is possible in this field to have multiple durations mentioned",
#                "title": "Details"
#             }
#          },
#          "required": [
#             "duration",
#             "details"
#          ],
#          "title": "StudyDuration",
#          "type": "object"
#       },
#       "StudyScope": {
#          "properties": {
#             "study_sites": {
#                "anyOf": [
#                   {
#                      "items": {
#                         "type": "string"
#                      },
#                      "type": "array"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "title": "Study Sites"
#             },
#             "description": {
#                "anyOf": [
#                   {
#                      "items": {
#                         "type": "string"
#                      },
#                      "type": "array"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "title": "Description"
#             },
#             "locations": {
#                "description": "Names of the actual locations",
#                "items": {
#                   "type": "string"
#                },
#                "title": "Locations",
#                "type": "array"
#             }
#          },
#          "required": [
#             "locations"
#          ],
#          "title": "StudyScope",
#          "type": "object"
#       },
#       "WeatherData": {
#          "properties": {
#             "time_period": {
#                "anyOf": [
#                   {
#                      "type": "string"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Time in which weather data was collected, or time window in which environmental variables were monitored",
#                "examples": [
#                   "Precipitation was collected during the monsoon season",
#                   "monthly weather data were monitored between 2001 and 2012"
#                ],
#                "title": "Time Period"
#             },
#             "details": {
#                "anyOf": [
#                   {
#                      "items": {
#                         "type": "string"
#                      },
#                      "type": "array"
#                   },
#                   {
#                      "type": "null"
#                   }
#                ],
#                "description": "Any sentence from the paper describing any info related to weather data that cannot be captured well in the above fields",
#                "examples": "Precipitations in Bangladesh were scarse during the 2005 fall",
#                "title": "Details"
#             },
#             "measurement": {
#                "description": "List of different measurements and methodologies used in the study.",
#                "items": {
#                   "$ref": "#/$defs/Measurement"
#                },
#                "title": "Measurement",
#                "type": "array"
#             }
#          },
#          "required": [
#             "time_period",
#             "details",
#             "measurement"
#          ],
#          "title": "WeatherData",
#          "type": "object"
#       }
#    },
#    "properties": {
#       "article_type": {
#          "anyOf": [
#             {
#                "type": "string"
#             },
#             {
#                "type": "null"
#             }
#          ],
#          "description": "Article type",
#          "examples": [
#             "Research article",
#             " meta-analysis",
#             "review",
#             "opinion paper"
#          ],
#          "title": "Article Type"
#       },
#       "study_type": {
#          "anyOf": [
#             {
#                "type": "string"
#             },
#             {
#                "type": "null"
#             }
#          ],
#          "description": "Type of study",
#          "examples": [
#             "retrospective study"
#          ],
#          "title": "Study Type"
#       },
#       "title": {
#          "description": "Title of the paper",
#          "title": "Title",
#          "type": "string"
#       },
#       "study_scope": {
#          "allOf": [
#             {
#                "$ref": "#/$defs/StudyScope"
#             }
#          ],
#          "default": []
#       },
#       "methodology": {
#          "default": [],
#          "items": {
#             "$ref": "#/$defs/Methodology"
#          },
#          "title": "Methodology",
#          "type": "array"
#       },
#       "study_duration": {
#          "allOf": [
#             {
#                "$ref": "#/$defs/StudyDuration"
#             }
#          ],
#          "default": []
#       },
#       "participant_age_group": {
#          "allOf": [
#             {
#                "$ref": "#/$defs/ParticipantAgeGroup"
#             }
#          ],
#          "default": []
#       },
#       "weather_data": {
#          "allOf": [
#             {
#                "$ref": "#/$defs/WeatherData"
#             }
#          ],
#          "default": []
#       },
#       "data_collection": {
#          "description": "When data was collected?",
#          "examples": [
#             "during 2008 to 2011"
#          ],
#          "title": "Data Collection",
#          "type": "string"
#       },
#       "authors": {
#          "description": "Authors of the paper. Usually listed below the title in the first page of the paper",
#          "examples": [
#             "Roose, A., Washington, D., Aniston, J.A."
#          ],
#          "title": "Authors",
#          "type": "string"
#       },
#       "affiliation": {
#          "description": "Affiliations of the authors listed in the authors field",
#          "examples": [
#             "Institute for Disease Modeling, Bellevue, Washington",
#             "International School for Advanced Studies, Trieste, Italy"
#          ],
#          "title": "Affiliation",
#          "type": "string"
#       },
#       "citation": {
#          "anyOf": [
#             {
#                "type": "string"
#             },
#             {
#                "type": "null"
#             }
#          ],
#          "description": "Citation of the paper which typically includes the first author surname followed by et al., and the year of publication along with the name of the journal",
#          "examples": [
#             "Roose et al., 2008, BMJ"
#          ],
#          "title": "Citation"
#       },
#       "corresponding_author": {
#          "description": "Author that has made available their email for further contact",
#          "examples": [
#             "r.roosevelt@gmail.com"
#          ],
#          "title": "Corresponding Author",
#          "type": "string"
#       },
#       "doi": {
#          "anyOf": [
#             {
#                "type": "string"
#             },
#             {
#                "type": "null"
#             }
#          ],
#          "title": "Doi"
#       },
#       "date": {
#          "description": "Date in which the paper has been published comprising typically day, month and year",
#          "examples": [
#             "06-08-2013"
#          ],
#          "title": "Date",
#          "type": "string"
#       },
#       "github_repo": {
#          "anyOf": [
#             {
#                "type": "string"
#             },
#             {
#                "type": "null"
#             }
#          ],
#          "description": "Github repository where code and data are available.",
#          "examples": "https://github.com/papermanuscript/main",
#          "title": "Github Repo"
#       },
#       "journal": {
#          "description": "Name of the journal in which the paper has been published, tipically listed in the front page, nearby the title",
#          "examples": "PLoS Negl Trop Dis",
#          "title": "Journal",
#          "type": "string"
#       }
#    },
#    "required": [
#       "article_type",
#       "study_type",
#       "title",
#       "data_collection",
#       "authors",
#       "affiliation",
#       "citation",
#       "corresponding_author",
#       "doi",
#       "date",
#       "github_repo",
#       "journal"
#    ],
#    "title": "Bibliography",
#    "type": "object"
# }
# /Users/evaviviani/opt/anaconda3/envs/py312/lib/python3.12/site-packages/pydantic/json_schema.py:2179: PydanticJsonSchemaWarning: Default value (FieldInfo(annotation=NoneType, required=True, description='sites studied and mentioned in the paper', examples=['The Gambia', 'Mali']),) is not JSON serializable; excluding default from JSON schema [non-serializable-default]
#   warnings.warn(message, PydanticJsonSchemaWarning)
# /Users/evaviviani/opt/anaconda3/envs/py312/lib/python3.12/site-packages/pydantic/json_schema.py:2179: PydanticJsonSchemaWarning: Default value (FieldInfo(annotation=NoneType, required=True, description='Sites/setting description in sentences which not necessarily contain the name of the site', examples='resource limited setting'),) is not JSON serializable; excluding default from JSON schema [non-serializable-default]
#   warnings.warn(message, PydanticJsonSchemaWarning)

# %%
empty_schema = Bibliography.schema_json(indent=3)
# Out:
# /Users/evaviviani/opt/anaconda3/envs/py312/lib/python3.12/site-packages/pydantic/json_schema.py:2179: PydanticJsonSchemaWarning: Default value (FieldInfo(annotation=NoneType, required=True, description='sites studied and mentioned in the paper', examples=['The Gambia', 'Mali']),) is not JSON serializable; excluding default from JSON schema [non-serializable-default]
#   warnings.warn(message, PydanticJsonSchemaWarning)
# /Users/evaviviani/opt/anaconda3/envs/py312/lib/python3.12/site-packages/pydantic/json_schema.py:2179: PydanticJsonSchemaWarning: Default value (FieldInfo(annotation=NoneType, required=True, description='Sites/setting description in sentences which not necessarily contain the name of the site', examples='resource limited setting'),) is not JSON serializable; excluding default from JSON schema [non-serializable-default]
#   warnings.warn(message, PydanticJsonSchemaWarning)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dict(empty_schema)
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required
